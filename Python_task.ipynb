# %% [markdown]
# Task: Create a quiz game made up of 5 questions. The user should be able to enter in answers and the final score calculated.
#
# Objective: To create a Python-based quiz game that allows users to answer 5 questions interactively and calculates their final score based on correct answers.
#
# Acceptance Criteria:
#
# The quiz contains exactly five questions.
# Questions and answers are stored in an easily modifiable structure (e.g., a list of dictionaries).
# The user can input their answers, and responses are case-insensitive.
# Correct answers increase the score, and incorrect answers display the correct answer.
# The final score is displayed at the end of the quiz.

# %%
def quiz_game():
    print("All answers must be in small-case")
    questions = [
        {"question": "What is the capital of Nigeria?", "answer": "abuja"},
        {"question": "How many planets are in the solar system? Type answer in words", "answer": "eight"},
        {"question": "What is the largest ocean on Earth?", "answer": "pacific"},
        {"question": "Who is the president of America?", "answer": "donald trump"},
        {"question": "What is the square root of 64? Type answer in figure", "answer": "8"}
    ]
    
    score = 0
    
    print("Welcome to the Quiz Game! Answer the following 5 questions:")
    
    for q in questions:
        user_answer = input(q["question"] + " ").strip().lower()
        if user_answer == q["answer"]:
            print("Correct!")
            score += 1
        else:
            print(f"Incorrect! The correct answer is {q['answer']}")
    
    print(f"\nQuiz Over! Your final score is {score} out of 5.")

# %%
quiz_game()
# Out:
# All answers must be in small-case
# Welcome to the Quiz Game! Answer the following 5 questions:
# What is the capital of Nigeria?  abuja
# Correct!
# How many planets are in the solar system? Type answer in words  eight
# Correct!
# What is the largest ocean on Earth?  pacific
# Correct!
# Who is the president of America?  donald trump
# Correct!
# What is the square root of 64? Type answer in figure  8
# Correct!
#
# Quiz Over! Your final score is 5 out of 5.

# %% [markdown]
# 2. Number Swapping
# Task: Swapping two numbers in Python.
#
# Objective: Create a Python program that swaps two numbers entered by the user and displays the values before and after swapping.
#
# Acceptance Criteria:
#
# The program accepts two numbers as input from the user.
# The numbers are displayed before and after swapping.
# The program uses Python’s tuple unpacking for swapping.
# Invalid input (non-numeric) is handled gracefully with an error message.
# The program successfully swaps the values without requiring a temporary variable.

# %%
def swap_numbers():
    try:
        # Get user input
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))
        
        print(f"Before swapping: num1 = {num1}, num2 = {num2}")
        
        # Swap using tuple unpacking
        num1, num2 = num2, num1
        
        print(f"After swapping: num1 = {num1}, num2 = {num2}")
    except ValueError:
        print("Invalid input! Please enter numeric values.")

# %%
swap_numbers()
# Out:
# Enter first number:  2
# Enter second number:  7
# Before swapping: num1 = 2.0, num2 = 7.0
# After swapping: num1 = 7.0, num2 = 2.0

# %% [markdown]
# 3. Prime/Armstrong/Palindrome Number Identifier
# Task: Write a code/logic to determine if the value entered is a Prime number, an Armstrong Number or a Palindrome number.
#
# Objective: To create a Python program that checks whether a user-entered number is a Prime number, Armstrong number, or Palindrome, and displays the results accordingly.
#
# Acceptance Criteria:
#
# The program accepts a single integer input from the user.
# It checks and identifies if the number is a:
# Prime number: A number greater than 1 that is divisible only by 1 and itself.
# Armstrong number: A number equal to the sum of its digits raised to the power of the number of digits.
# Palindrome: A number that reads the same backward as forward.
# The program displays appropriate messages for each property satisfied by the number.
# If the number does not meet any criteria, a message is displayed stating so.
# Non-integer input is handled gracefully with an error message.

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, n):
        if n % i == 0:
            return False
    return True

def is_armstrong(n):
    num_str = str(n)
    total = 0
    for digit in num_str:
        total += int(digit) ** len(num_str)
    return total == n

def is_palindrome(n):
    return str(n) == str(n)[::-1]

def number_identifier():
    try:
        num = int(input("Enter a number: "))
        
        if is_prime(num):
            print(f"{num} is a Prime number.")
        if is_armstrong(num):
            print(f"{num} is an Armstrong number.")
        if is_palindrome(num):
            print(f"{num} is a Palindrome number.")
        if not (is_prime(num) or is_armstrong(num) or is_palindrome(num)):
            print(f"{num} does not match any category.")
    except ValueError:
        print("Please enter a valid number.")

# %%
number_identifier()
# Out:
# Enter a number:  2002
# 2002 is a Palindrome number.

# %% [markdown]
# Question 4. The Fibonacci Sequence
# Task: Generate the Fibonacci Sequence.
#
# Objective: To create a Python program that generates the first n terms of the Fibonacci sequence based on user input.
#
# Acceptance Criteria:
#
# The program accepts a positive integer input (n) from the user.
# It generates and displays the first n terms of the Fibonacci sequence.
# The Fibonacci sequence is calculated iteratively.
# If the input is zero or negative, an appropriate error message is displayed.
# Non-integer input is handled gracefully with an error message.

# %%
def fibonacci_sequence():
    try:
        n = int(input("Enter a positive number: "))
        
        if n <= 0:
            print("Please enter a number greater than zero.")
            return
        
        a, b = 0, 1
        fib_list = []
        for _ in range(n):
            fib_list.append(a)
            a, b = b, a + b
        
        print("Fibonacci Sequence:", fib_list)
    except ValueError:
        print("Please enter a valid number.")

# %%
fibonacci_sequence()
# Out:
# Enter a positive number:  4
# Fibonacci Sequence: [0, 1, 1, 2]

# %% [markdown]
# Review
# Summary of Submission:
# The student has provided solutions for all four tasks in Python programming as per the instructor's instructions. Below is a detailed review of each task:
#
# Quiz Game
# Strengths:
#
# Includes exactly 5 questions, satisfying the acceptance criteria.
# Questions and answers are stored in a list of dictionaries, making them easily modifiable.
# Answer validation is case-insensitive, which enhances usability.
# Final score is calculated and displayed correctly.
# Feedback for correct and incorrect answers is implemented effectively.
# Weaknesses:
#
# Input validation for non-alphabetic user responses is missing. For example, the question "How many planets are in the solar system?" expects "eight," but if numbers or other invalid inputs are entered, the program does not handle them gracefully or display an explanatory validation message.
# The user prompt has a hard-coded instruction that requires all answers in small-case. This could be misleading since case-insensitive validation is already provided.
# Number Swapping
# Strengths:
#
# Handles invalid input gracefully with a clear error message when non-numeric values are entered.
# Tuple unpacking for swapping numbers is implemented as required.
# Displays the values before and after swapping clearly, enhancing user experience.
# Weaknesses: No significant weaknesses; this implementation is robust and meets all acceptance criteria.
#
# Prime/Armstrong/Palindrome Number Identifier
# Strengths:
#
# Thorough validation of number properties (prime, Armstrong, palindrome) using modular functions.
# Error handling for invalid (non-integer) input is well-implemented.
# Accurately displays results for each category satisfied and provides feedback when none of the conditions are met.
# Weaknesses:
#
# The is_prime function checks divisors up to n - 1, which makes it less efficient for larger numbers. Ideally, the range should be up to sqrt(n) to optimize performance.
# Fibonacci Sequence
# Strengths:
#
# Iterative calculation of the Fibonacci sequence is correct.
# Handles invalid input (non-integer or non-positive numbers) gracefully.
# Provides clear and concise output displaying the generated sequence.
# Weaknesses:
#
# In cases where the user enters 1, the output correctly displays [0], but there could be a small improvement in user clarity (e.g., explaining why the result starts at zero).
# There is no additional message explaining why negative or zero values are invalid, leaving potential ambiguity.
# Grading Criteria:
# Correctness and Functionality (40 Points): All activities function as intended, follow the acceptance criteria, and produce the correct outputs. Minor efficiency concerns (e.g., is_prime inefficiency).
# Score: 38/40
#
# User Input Validation and Error Handling (20 Points): Error handling is generally robust, but minor improvements are needed in user response validation for the Quiz Game.
# Score: 18/20
#
# Code Quality and Readability (20 Points): Code is clean, well-structured, with descriptive variable names and proper comments. The Fibonacci solution could explain edge cases a little better.
# Score: 19/20
#
# User Interaction and Output Presentation (20 Points): Outputs are detailed, clear, and provide meaningful feedback. A minor concern is the hard-coded instruction for the Quiz Game requiring answers in small-case.
# Score: 18/20
#
# Total Score:
# The student has demonstrated strong understanding and implementation of Python programming fundamentals, interactive coding, and problem-solving. Minor issues related to input validation, efficiency, and clarity prevent the submission from achieving a perfect score.
